# %%
import sys

import numpy as np
import pandas as pd

sys.path.insert(0, '..')
from skew.plot_context import *
from skew.make_context_matrices_and_summarize_context import *

# %load_ext autoreload
# %autoreload 2

# %%
feature_x_sample = pd.read_table('feature_x_sample.tsv', index_col=0)
feature_x_sample
# Out:
#         22RV1_PROSTATE  697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  786O_KIDNEY  \
# KRAS          2.431950                                2.285786     0.093278
# SOX10        -1.729977                                1.724498     0.785717
# ERBB3         1.021403                                0.712437    -1.100162
# MYC           1.775596                                1.147762    -1.435271
# MAP4K4        2.066341                               -1.407940     0.790867
# GAPDH         3.396082                               -1.558858    -2.408117
# FAT1          0.220865                               -1.712152     0.526265
# PTEN         -1.100954                               -0.011806    -1.834946
# TP53         -0.659688                                2.229142    -0.881906
#
#         A1207_CENTRAL_NERVOUS_SYSTEM  A172_CENTRAL_NERVOUS_SYSTEM  \
# KRAS                       -0.715936                     1.446825
# SOX10                      -1.777906                     1.183808
# ERBB3                       0.785717                     1.013481
# MYC                         2.407392                     2.166557
# MAP4K4                      0.523096                     1.990684
# GAPDH                       4.163743                    -1.689970
# FAT1                        0.066738                    -0.680682
# PTEN                       -0.302397                    -1.692347
# TP53                        2.277468                     1.315316
#
#         A204_SOFT_TISSUE  A2058_SKIN  A549_LUNG  A673_BONE  ACHN_KIDNEY  \
# KRAS            1.937605    1.022591  -1.911792   1.947112     1.467027
# SOX10          -0.975388   -5.992516   0.625689   1.845708    -1.114818
# ERBB3           0.091852    0.655001  -0.131000   0.709268     0.193652
# MYC             0.910492    1.991476  -0.421626   0.796412     0.927129
# MAP4K4          0.792451    1.999794  -0.759904  -0.102242     0.269784
# GAPDH           4.258810   -3.452659   2.090504  -0.743267     4.488553
# FAT1            0.369921   -0.762280  -0.769014  -0.406970    -1.101747
# PTEN           -0.164115   -0.849821  -0.558284  -1.029259    -1.683632
# TP53            2.018016   -2.274232   0.403867  -1.410316     0.447439
#
#             ...       UACC812_BREAST  WM115_SKIN  WM1799_SKIN  WM2664_SKIN  \
# KRAS        ...            -0.277204    1.194503    -0.324539     1.049923
# SOX10       ...             0.809880   -8.072094    -1.209092    -6.693631
# ERBB3       ...            -6.012322    2.102783     0.863751     0.895440
# MYC         ...             0.818991    1.921365    -1.837323    -0.507978
# MAP4K4      ...             0.022623   -0.197348     0.069709     0.363939
# GAPDH       ...             3.088701    3.436089    -2.498034     3.822296
# FAT1        ...            -1.074415   -0.477477     0.133958    -0.710786
# PTEN        ...            -1.581040   -0.725442     0.109399    -0.209152
# TP53        ...            -0.821697    5.142135     1.092703     6.433453
#
#         WM793_SKIN  WM88_SKIN  WM983B_SKIN  YD38_UPPER_AERODIGESTIVE_TRACT  \
# KRAS      0.322982   0.393212    -0.426775                       -1.032427
# SOX10    -8.448398  -4.202099    -7.521501                       -0.192991
# ERBB3    -0.205627   1.639730     1.198464                       -1.981507
# MYC      -0.157262   1.705485    -1.593715                       -2.390292
# MAP4K4    3.109298   0.829686     2.083770                        2.391151
# GAPDH    -2.300772   1.083196    -1.591735                       -0.957959
# FAT1     -1.296237  -0.332263     1.385824                        0.458531
# PTEN     -0.649785  -1.444382     1.653594                        0.438725
# TP53      2.424820   2.496912    -0.793177                       -1.375063
#
#         YD8_UPPER_AERODIGESTIVE_TRACT  ZR751_BREAST
# KRAS                         2.210129     -0.738514
# SOX10                       -1.535883      1.274517
# ERBB3                       -0.980537     -0.663253
# MYC                         -0.879529     -1.463791
# MAP4K4                       2.629609     -0.860912
# GAPDH                       -2.087268      2.035444
# FAT1                         1.329972     -0.182415
# PTEN                         1.308979     -1.032427
# TP53                        -2.045281      2.094465
#
# [9 rows x 501 columns]

# %%
context__feature_x_sample, feature_context_summary, no_context__feature_x_sample = make_context_matrices_and_summarize_context(
    feature_x_sample)
# Out:
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in sqrt
#   Shat = sqrt(mu2hat / mu2)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in sqrt
#   Shat = sqrt(mu2hat / mu2)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:4290: RuntimeWarning: overflow encountered in double_scalars
#   Px /= np.sqrt(r*np.pi)*(1+(x**2)/r)**((r+1)/2)

# %%
feature_x_sample
# Out:
#         22RV1_PROSTATE  697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  786O_KIDNEY  \
# KRAS          2.431950                                2.285786     0.093278
# SOX10        -1.729977                                1.724498     0.785717
# ERBB3         1.021403                                0.712437    -1.100162
# MYC           1.775596                                1.147762    -1.435271
# MAP4K4        2.066341                               -1.407940     0.790867
# GAPDH         3.396082                               -1.558858    -2.408117
# FAT1          0.220865                               -1.712152     0.526265
# PTEN         -1.100954                               -0.011806    -1.834946
# TP53         -0.659688                                2.229142    -0.881906
#
#         A1207_CENTRAL_NERVOUS_SYSTEM  A172_CENTRAL_NERVOUS_SYSTEM  \
# KRAS                       -0.715936                     1.446825
# SOX10                      -1.777906                     1.183808
# ERBB3                       0.785717                     1.013481
# MYC                         2.407392                     2.166557
# MAP4K4                      0.523096                     1.990684
# GAPDH                       4.163743                    -1.689970
# FAT1                        0.066738                    -0.680682
# PTEN                       -0.302397                    -1.692347
# TP53                        2.277468                     1.315316
#
#         A204_SOFT_TISSUE  A2058_SKIN  A549_LUNG  A673_BONE  ACHN_KIDNEY  \
# KRAS            1.937605    1.022591  -1.911792   1.947112     1.467027
# SOX10          -0.975388   -5.992516   0.625689   1.845708    -1.114818
# ERBB3           0.091852    0.655001  -0.131000   0.709268     0.193652
# MYC             0.910492    1.991476  -0.421626   0.796412     0.927129
# MAP4K4          0.792451    1.999794  -0.759904  -0.102242     0.269784
# GAPDH           4.258810   -3.452659   2.090504  -0.743267     4.488553
# FAT1            0.369921   -0.762280  -0.769014  -0.406970    -1.101747
# PTEN           -0.164115   -0.849821  -0.558284  -1.029259    -1.683632
# TP53            2.018016   -2.274232   0.403867  -1.410316     0.447439
#
#             ...       UACC812_BREAST  WM115_SKIN  WM1799_SKIN  WM2664_SKIN  \
# KRAS        ...            -0.277204    1.194503    -0.324539     1.049923
# SOX10       ...             0.809880   -8.072094    -1.209092    -6.693631
# ERBB3       ...            -6.012322    2.102783     0.863751     0.895440
# MYC         ...             0.818991    1.921365    -1.837323    -0.507978
# MAP4K4      ...             0.022623   -0.197348     0.069709     0.363939
# GAPDH       ...             3.088701    3.436089    -2.498034     3.822296
# FAT1        ...            -1.074415   -0.477477     0.133958    -0.710786
# PTEN        ...            -1.581040   -0.725442     0.109399    -0.209152
# TP53        ...            -0.821697    5.142135     1.092703     6.433453
#
#         WM793_SKIN  WM88_SKIN  WM983B_SKIN  YD38_UPPER_AERODIGESTIVE_TRACT  \
# KRAS      0.322982   0.393212    -0.426775                       -1.032427
# SOX10    -8.448398  -4.202099    -7.521501                       -0.192991
# ERBB3    -0.205627   1.639730     1.198464                       -1.981507
# MYC      -0.157262   1.705485    -1.593715                       -2.390292
# MAP4K4    3.109298   0.829686     2.083770                        2.391151
# GAPDH    -2.300772   1.083196    -1.591735                       -0.957959
# FAT1     -1.296237  -0.332263     1.385824                        0.458531
# PTEN     -0.649785  -1.444382     1.653594                        0.438725
# TP53      2.424820   2.496912    -0.793177                       -1.375063
#
#         YD8_UPPER_AERODIGESTIVE_TRACT  ZR751_BREAST
# KRAS                         2.210129     -0.738514
# SOX10                       -1.535883      1.274517
# ERBB3                       -0.980537     -0.663253
# MYC                         -0.879529     -1.463791
# MAP4K4                       2.629609     -0.860912
# GAPDH                       -2.087268      2.035444
# FAT1                         1.329972     -0.182415
# PTEN                         1.308979     -1.032427
# TP53                        -2.045281      2.094465
#
# [9 rows x 501 columns]

# %%
context__feature_x_sample
# Out:
#          22RV1_PROSTATE  697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   786O_KIDNEY  \
# Feature
# KRAS           0.000000                            0.000000e+00 -4.463940e-01
# SOX10         -0.877715                            0.000000e+00  0.000000e+00
# ERBB3          0.000000                            0.000000e+00 -3.220198e-01
# MYC            0.631304                            3.296054e-01 -0.000000e+00
# MAP4K4         0.000000                           -6.296055e-03  0.000000e+00
# GAPDH          0.126684                           -0.000000e+00 -0.000000e+00
# FAT1           0.000000                           -0.000000e+00  7.614862e-08
# PTEN          -0.000000                            8.962171e-08 -0.000000e+00
# TP53           0.559659                            9.999999e-01  3.798596e-01
#
#          A1207_CENTRAL_NERVOUS_SYSTEM  A172_CENTRAL_NERVOUS_SYSTEM  \
# Feature
# KRAS                    -8.508802e-01                     0.000000
# SOX10                   -8.904818e-01                     0.000000
# ERBB3                    0.000000e+00                     0.000000
# MYC                      8.556590e-01                     0.784471
# MAP4K4                   0.000000e+00                     0.000000
# GAPDH                    3.482639e-01                    -0.000000
# FAT1                     0.000000e+00                    -0.000000
# PTEN                     9.225944e-13                    -0.000000
# TP53                     1.000000e+00                     0.999839
#
#          A204_SOFT_TISSUE  A2058_SKIN     A549_LUNG     A673_BONE  \
# Feature
# KRAS         0.000000e+00   -0.000000 -9.963062e-01  0.000000e+00
# SOX10       -5.169802e-01   -1.000000  0.000000e+00  0.000000e+00
# ERBB3       -0.000000e+00    0.000000 -0.000000e+00  0.000000e+00
# MYC          2.245407e-01    0.720997  0.000000e+00  1.802385e-01
# MAP4K4       0.000000e+00    0.000000 -0.000000e+00 -0.000000e+00
# GAPDH        3.812057e-01   -0.000000  4.508259e-03  7.388927e-19
# FAT1         0.000000e+00   -0.000000 -0.000000e+00 -0.000000e+00
# PTEN         6.052292e-10   -0.000000  4.299797e-25 -0.000000e+00
# TP53         9.999995e-01   -0.000000  9.766038e-01  0.000000e+00
#
#          ACHN_KIDNEY      ...       UACC812_BREAST  WM115_SKIN  WM1799_SKIN  \
# Feature                   ...
# KRAS        0.000000      ...            -0.665449    0.000000    -0.690062
# SOX10      -0.603739      ...             0.000000   -1.000000    -0.657474
# ERBB3      -0.000000      ...            -1.000000    0.000000     0.000000
# MYC         0.230975      ...             0.189051    0.692997    -0.000000
# MAP4K4      0.000000      ...            -0.000000   -0.000000    -0.000000
# GAPDH       0.463047      ...             0.071544    0.135707    -0.000000
# FAT1       -0.000000      ...            -0.000000   -0.000000     0.000000
# PTEN       -0.000000      ...            -0.000000   -0.000000     0.000002
# TP53        0.980439      ...             0.431309    1.000000     0.999307
#
#           WM2664_SKIN  WM793_SKIN  WM88_SKIN  WM983B_SKIN  \
# Feature
# KRAS    -0.000000e+00    -0.28432  -0.229011    -0.739816
# SOX10   -1.000000e+00    -1.00000  -0.999996    -1.000000
# ERBB3    0.000000e+00    -0.00000   0.000000     0.000000
# MYC      0.000000e+00     0.00000   0.599551    -0.000000
# MAP4K4   0.000000e+00     0.00000   0.000000     0.000000
# GAPDH    2.385730e-01    -0.00000   0.000035    -0.000000
# FAT1    -0.000000e+00    -0.00000  -0.000000     0.046904
# PTEN     9.372584e-11    -0.00000  -0.000000     0.679370
# TP53     1.000000e+00     1.00000   1.000000     0.458301
#
#          YD38_UPPER_AERODIGESTIVE_TRACT  YD8_UPPER_AERODIGESTIVE_TRACT  \
# Feature
# KRAS                      -9.299422e-01                       0.000000
# SOX10                     -1.127148e-02                      -0.812048
# ERBB3                     -8.369575e-01                      -0.247981
# MYC                       -0.000000e+00                      -0.000000
# MAP4K4                     0.000000e+00                       0.000000
# GAPDH                      1.245142e-30                      -0.000000
# FAT1                       1.300312e-09                       0.031885
# PTEN                       6.200229e-04                       0.338415
# TP53                       0.000000e+00                      -0.000000
#
#          ZR751_BREAST
# Feature
# KRAS        -0.858360
# SOX10        0.000000
# ERBB3       -0.092319
# MYC         -0.000000
# MAP4K4      -0.000000
# GAPDH        0.003709
# FAT1        -0.000000
# PTEN        -0.000000
# TP53         1.000000
#
# [9 rows x 501 columns]

# %%
feature_x_sample.abs() * context__feature_x_sample
# Out:
#         22RV1_PROSTATE  697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   786O_KIDNEY  \
# KRAS          0.000000                            0.000000e+00 -4.163854e-02
# SOX10        -1.518427                            0.000000e+00  0.000000e+00
# ERBB3         0.000000                            0.000000e+00 -3.542740e-01
# MYC           1.120942                            3.783085e-01 -0.000000e+00
# MAP4K4        0.000000                           -8.864466e-03  0.000000e+00
# GAPDH         0.430228                           -0.000000e+00 -0.000000e+00
# FAT1          0.000000                           -0.000000e+00  4.007438e-08
# PTEN         -0.000000                            1.058116e-09 -0.000000e+00
# TP53          0.369201                            2.229142e+00  3.350003e-01
#
#         A1207_CENTRAL_NERVOUS_SYSTEM  A172_CENTRAL_NERVOUS_SYSTEM  \
# KRAS                   -6.091754e-01                     0.000000
# SOX10                  -1.583193e+00                     0.000000
# ERBB3                   0.000000e+00                     0.000000
# MYC                     2.059906e+00                     1.699601
# MAP4K4                  0.000000e+00                     0.000000
# GAPDH                   1.450081e+00                    -0.000000
# FAT1                    0.000000e+00                    -0.000000
# PTEN                    2.789895e-13                    -0.000000
# TP53                    2.277467e+00                     1.315105
#
#         A204_SOFT_TISSUE  A2058_SKIN     A549_LUNG     A673_BONE  ACHN_KIDNEY  \
# KRAS        0.000000e+00   -0.000000 -1.904730e+00  0.000000e+00     0.000000
# SOX10      -5.042560e-01   -5.992516  0.000000e+00  0.000000e+00    -0.673059
# ERBB3      -0.000000e+00    0.000000 -0.000000e+00  0.000000e+00    -0.000000
# MYC         2.044426e-01    1.435847  0.000000e+00  1.435442e-01     0.214143
# MAP4K4      0.000000e+00    0.000000 -0.000000e+00 -0.000000e+00     0.000000
# GAPDH       1.623482e+00   -0.000000  9.424532e-03  5.491946e-19     2.078413
# FAT1        0.000000e+00   -0.000000 -0.000000e+00 -0.000000e+00    -0.000000
# PTEN        9.932702e-11   -0.000000  2.400507e-25 -0.000000e+00    -0.000000
# TP53        2.018014e+00   -0.000000  3.944184e-01  0.000000e+00     0.438687
#
#             ...       UACC812_BREAST  WM115_SKIN   WM1799_SKIN   WM2664_SKIN  \
# KRAS        ...            -0.184465    0.000000 -2.239523e-01 -0.000000e+00
# SOX10       ...             0.000000   -8.072094 -7.949471e-01 -6.693631e+00
# ERBB3       ...            -6.012322    0.000000  0.000000e+00  0.000000e+00
# MYC         ...             0.154831    1.331500 -0.000000e+00  0.000000e+00
# MAP4K4      ...            -0.000000   -0.000000 -0.000000e+00  0.000000e+00
# GAPDH       ...             0.220978    0.466300 -0.000000e+00  9.118966e-01
# FAT1        ...            -0.000000   -0.000000  0.000000e+00 -0.000000e+00
# PTEN        ...            -0.000000   -0.000000  2.090230e-07  1.960299e-11
# TP53        ...             0.354405    5.142135  1.091945e+00  6.433453e+00
#
#         WM793_SKIN  WM88_SKIN  WM983B_SKIN  YD38_UPPER_AERODIGESTIVE_TRACT  \
# KRAS     -0.091830  -0.090050    -0.315735                   -9.600978e-01
# SOX10    -8.448398  -4.202081    -7.521501                   -2.175296e-03
# ERBB3    -0.000000   0.000000     0.000000                   -1.658437e+00
# MYC       0.000000   1.022525    -0.000000                   -0.000000e+00
# MAP4K4    0.000000   0.000000     0.000000                    0.000000e+00
# GAPDH    -0.000000   0.000037    -0.000000                    1.192795e-30
# FAT1     -0.000000  -0.000000     0.065000                    5.962327e-10
# PTEN     -0.000000  -0.000000     1.123403                    2.720196e-04
# TP53      2.424820   2.496912     0.363514                    0.000000e+00
#
#         YD8_UPPER_AERODIGESTIVE_TRACT  ZR751_BREAST
# KRAS                         0.000000     -0.633911
# SOX10                       -1.247211      0.000000
# ERBB3                       -0.243154     -0.061231
# MYC                         -0.000000     -0.000000
# MAP4K4                       0.000000     -0.000000
# GAPDH                       -0.000000      0.007549
# FAT1                         0.042406     -0.000000
# PTEN                         0.442978     -0.000000
# TP53                        -0.000000      2.094464
#
# [9 rows x 501 columns]

# %%
no_context__feature_x_sample
# Out:
#          22RV1_PROSTATE  697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  786O_KIDNEY  \
# Feature
# KRAS               True                                    True         True
# SOX10             False                                    True         True
# ERBB3              True                                    True        False
# MYC               False                                    True         True
# MAP4K4             True                                    True         True
# GAPDH             False                                    True         True
# FAT1               True                                    True         True
# PTEN               True                                    True         True
# TP53               True                                   False         True
#
#          A1207_CENTRAL_NERVOUS_SYSTEM  A172_CENTRAL_NERVOUS_SYSTEM  \
# Feature
# KRAS                             True                         True
# SOX10                           False                         True
# ERBB3                            True                         True
# MYC                             False                        False
# MAP4K4                           True                         True
# GAPDH                           False                         True
# FAT1                             True                         True
# PTEN                             True                         True
# TP53                            False                         True
#
#          A204_SOFT_TISSUE  A2058_SKIN  A549_LUNG  A673_BONE  ACHN_KIDNEY  \
# Feature
# KRAS                 True        True      False       True         True
# SOX10                True       False       True       True        False
# ERBB3                True        True       True       True         True
# MYC                  True       False       True       True         True
# MAP4K4               True        True       True       True         True
# GAPDH               False        True       True       True        False
# FAT1                 True        True       True       True         True
# PTEN                 True        True       True       True         True
# TP53                 True        True       True       True         True
#
#              ...       UACC812_BREAST  WM115_SKIN  WM1799_SKIN  WM2664_SKIN  \
# Feature      ...
# KRAS         ...                 True        True         True         True
# SOX10        ...                 True       False        False        False
# ERBB3        ...                False        True         True         True
# MYC          ...                 True       False         True         True
# MAP4K4       ...                 True        True         True         True
# GAPDH        ...                False       False         True        False
# FAT1         ...                 True        True         True         True
# PTEN         ...                 True        True         True         True
# TP53         ...                 True       False         True        False
#
#          WM793_SKIN  WM88_SKIN  WM983B_SKIN  YD38_UPPER_AERODIGESTIVE_TRACT  \
# Feature
# KRAS           True       True         True                            True
# SOX10         False      False        False                            True
# ERBB3          True       True         True                           False
# MYC            True      False         True                            True
# MAP4K4         True       True         True                            True
# GAPDH          True       True         True                            True
# FAT1           True       True        False                            True
# PTEN           True       True        False                            True
# TP53          False      False         True                            True
#
#          YD8_UPPER_AERODIGESTIVE_TRACT  ZR751_BREAST
# Feature
# KRAS                              True          True
# SOX10                            False          True
# ERBB3                             True          True
# MYC                               True          True
# MAP4K4                            True          True
# GAPDH                             True          True
# FAT1                             False          True
# PTEN                             False          True
# TP53                              True         False
#
# [9 rows x 501 columns]

# %%
(-0.75 < context__feature_x_sample) | (context__feature_x_sample < 0.75)
# Out:
#          22RV1_PROSTATE  697_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  786O_KIDNEY  \
# Feature
# KRAS               True                                    True         True
# SOX10              True                                    True         True
# ERBB3              True                                    True         True
# MYC                True                                    True         True
# MAP4K4             True                                    True         True
# GAPDH              True                                    True         True
# FAT1               True                                    True         True
# PTEN               True                                    True         True
# TP53               True                                    True         True
#
#          A1207_CENTRAL_NERVOUS_SYSTEM  A172_CENTRAL_NERVOUS_SYSTEM  \
# Feature
# KRAS                             True                         True
# SOX10                            True                         True
# ERBB3                            True                         True
# MYC                              True                         True
# MAP4K4                           True                         True
# GAPDH                            True                         True
# FAT1                             True                         True
# PTEN                             True                         True
# TP53                             True                         True
#
#          A204_SOFT_TISSUE  A2058_SKIN  A549_LUNG  A673_BONE  ACHN_KIDNEY  \
# Feature
# KRAS                 True        True       True       True         True
# SOX10                True        True       True       True         True
# ERBB3                True        True       True       True         True
# MYC                  True        True       True       True         True
# MAP4K4               True        True       True       True         True
# GAPDH                True        True       True       True         True
# FAT1                 True        True       True       True         True
# PTEN                 True        True       True       True         True
# TP53                 True        True       True       True         True
#
#              ...       UACC812_BREAST  WM115_SKIN  WM1799_SKIN  WM2664_SKIN  \
# Feature      ...
# KRAS         ...                 True        True         True         True
# SOX10        ...                 True        True         True         True
# ERBB3        ...                 True        True         True         True
# MYC          ...                 True        True         True         True
# MAP4K4       ...                 True        True         True         True
# GAPDH        ...                 True        True         True         True
# FAT1         ...                 True        True         True         True
# PTEN         ...                 True        True         True         True
# TP53         ...                 True        True         True         True
#
#          WM793_SKIN  WM88_SKIN  WM983B_SKIN  YD38_UPPER_AERODIGESTIVE_TRACT  \
# Feature
# KRAS           True       True         True                            True
# SOX10          True       True         True                            True
# ERBB3          True       True         True                            True
# MYC            True       True         True                            True
# MAP4K4         True       True         True                            True
# GAPDH          True       True         True                            True
# FAT1           True       True         True                            True
# PTEN           True       True         True                            True
# TP53           True       True         True                            True
#
#          YD8_UPPER_AERODIGESTIVE_TRACT  ZR751_BREAST
# Feature
# KRAS                              True          True
# SOX10                             True          True
# ERBB3                             True          True
# MYC                               True          True
# MAP4K4                            True          True
# GAPDH                             True          True
# FAT1                              True          True
# PTEN                              True          True
# TP53                              True          True
#
# [9 rows x 501 columns]

# %%
feature = 'ERBB3'
plot_context(feature_x_sample.loc[feature], feature)
# Out:
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
# /home/k/Jumis/conda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in sqrt
#   Shat = sqrt(mu2hat / mu2)
